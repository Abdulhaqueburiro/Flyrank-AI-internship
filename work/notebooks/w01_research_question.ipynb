# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# # 1. My lane (or freestyle) and why
#
# **Lane:** Content Refresh Prioritization
#
# I chose the Content Refresh Prioritization lane because it focuses on identifying pages that are most likely to need a content refresh. Instead of checking every page manually, data can help prioritize which pages should be reviewed first. This can save time and support better SEO decisions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# # 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which pages should be reviewed first for content refresh?
#
# **Action:** The SEO team reviews and updates the highest-priority pages.
#
# **Cost of a wrong recommendation:** If an important declining page is missed, traffic may continue to decrease. If a healthy page is selected unnecessarily, time and effort are wasted.
#
# Machine learning can help combine multiple signals to rank pages instead of relying only on manual rules.

# %%
import os
import subprocess

if not os.path.exists("Flyrank-AI-internship"):
    subprocess.run([
        "git",
        "clone",
        "https://github.com/Abdulhaqueburiro/Flyrank-AI-internship.git"
    ])

os.chdir("Flyrank-AI-internship")

print("Current folder:", os.getcwd())
# Out:
# Current folder: /content/Flyrank-AI-internship/Flyrank-AI-internship

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

corr = df["search_volume"].corr(df["impressions_90d"])
print("Correlation:", round(corr, 3))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Rows: 30000
# Columns: 44
# Correlation: 0.001
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
with open("docs/ml-intern-dataset-and-lane-guide.md", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# # FlyRank ML Internship - Your Dataset and Lane Guide
#
# Status: your guide for the Applied Search Intelligence track.
#
# Read this together with:
#
# - `docs/ml-core-foundation-framework.md` (ships in this repo — a deep reference, not week-one reading)
# - `docs/intern-free-tooling-guide.md` (ships in this repo)
# - the week-by-week curriculum on your portal board
# - the data dictionary and manifest that ship inside the dataset release on Hugging Face
#
# > This starter repo ships only the small anonymized starter dataset (`data/raw/content_refresh_anonymized.csv`).
# > The much larger warehouse release lives on Hugging Face at
# > [`FlyRank/internship-warehouse`](https://huggingface.co/datasets/FlyRank/internship-warehouse).
# > It is gated, which means you click "request access" and accept the data-use terms first —
# > approval is instant, so you can get it yourself whenever your lane needs it.
#
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ yes] Every section above is filled — markdown thinking AND the code that backs it
# - [yes ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ yes] No client names, URLs, or private queries anywhere
# - [ yes] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# # 3. Quick look at the data
#
# The starter dataset contains **30,000 pages** and **44 columns**.
#
# The correlation between **search_volume** and **impressions_90d** is **0.001**, suggesting almost no relationship between these two variables.
#
# The dataset also contains many declining pages, making it useful for studying content refresh prioritization.

# %% [markdown]
# # 4. Careful words: what I can and can't claim
#
# This project provides decision support by identifying patterns in the available data.
#
# The findings should be treated as observed and directional, not as proof.
#
# This project cannot predict Google's algorithm or guarantee that refreshing a page will improve its ranking.
