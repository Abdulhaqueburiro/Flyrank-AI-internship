# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulhaqueburiro/Flyrank-AI-internship/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
unit_of_analysis = """
One row represents one webpage for one day.
Time window: March 2026.
The goal is to analyze search performance and identify pages that need optimization.
"""

print(unit_of_analysis)
# Out:
# One row represents one webpage for one day.
# Time window: March 2026.
# The goal is to analyze search performance and identify pages that need optimization.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
fields = {
    "Features": [
        "impressions",
        "clicks",
        "ctr",
        "position",
        "page"
    ],
    "Label": "Low CTR with high impressions",
    "Context": [
        "date",
        "country",
        "device"
    ],
    "Excluded": {
        "future_clicks": "Excluded because it would cause data leakage."
    }
}

print(fields)
# Out:
# {'Features': ['impressions', 'clicks', 'ctr', 'position', 'page'], 'Label': 'Low CTR with high impressions', 'Context': ['date', 'country', 'device'], 'Excluded': {'future_clicks': 'Excluded because it would cause data leakage.'}}

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

data = {
    "page": ["/home", "/blog", "/pricing"],
    "date": ["2026-03-01", "2026-03-01", "2026-03-01"],
    "impressions": [1200, 850, 400],
    "clicks": [45, 30, 10],
    "ctr": [3.75, 3.53, 2.50],
    "position": [8.2, 10.5, 14.1]
}

df = pd.DataFrame(data)

print("Rows:", len(df))
print("Columns:", list(df.columns))
print("Missing values:")
print(df.isnull().sum())
print("Date range:", df["date"].min(), "to", df["date"].max())
# Out:
# Rows: 3
# Columns: ['page', 'date', 'impressions', 'clicks', 'ctr', 'position']
# Missing values:
# page           0
# date           0
# impressions    0
# clicks         0
# ctr            0
# position       0
# dtype: int64
# Date range: 2026-03-01 to 2026-03-01

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
limitations = """
This dataset only contains search performance data.
It cannot explain user intent or conversions.
Results are based on historical observations and should be used for decision support only.
"""

print(limitations)
# Out:
# This dataset only contains search performance data.
# It cannot explain user intent or conversions.
# Results are based on historical observations and should be used for decision support only.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
